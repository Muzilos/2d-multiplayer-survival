# %%
# Installation
# ! pip install smolagents
# !pip install huggingface_hub
# from huggingface_hub import notebook_login
# notebook_login()

# !pip install 'smolagents[toolkit]'
# !pip install 'smolagents[litellm]'
# !pip install 'smolagents[transformers]'

# To install from source instead of the last release, comment the command above and uncomment the following one.
# ! pip install git+https://github.com/huggingface/smolagents.git
# Out:
# Requirement already satisfied: smolagents[toolkit] in /usr/local/lib/python3.12/dist-packages (1.22.0)
# Requirement already satisfied: huggingface-hub>=0.31.2 in /usr/local/lib/python3.12/dist-packages (from smolagents[toolkit]) (0.36.0)
# Requirement already satisfied: requests>=2.32.3 in /usr/local/lib/python3.12/dist-packages (from smolagents[toolkit]) (2.32.4)
# Requirement already satisfied: rich>=13.9.4 in /usr/local/lib/python3.12/dist-packages (from smolagents[toolkit]) (13.9.4)
# Requirement already satisfied: jinja2>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from smolagents[toolkit]) (3.1.6)
# Requirement already satisfied: pillow>=10.0.1 in /usr/local/lib/python3.12/dist-packages (from smolagents[toolkit]) (11.3.0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from smolagents[toolkit]) (1.2.1)
# Requirement already satisfied: ddgs>=9.0.0 in /usr/local/lib/python3.12/dist-packages (from smolagents[toolkit]) (9.8.0)
# Requirement already satisfied: markdownify>=0.14.1 in /usr/local/lib/python3.12/dist-packages (from smolagents[toolkit]) (1.2.0)
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.12/dist-packages (from ddgs>=9.0.0->smolagents[toolkit]) (8.3.0)
# Requirement already satisfied: primp>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from ddgs>=9.0.0->smolagents[toolkit]) (0.15.0)
# Requirement already satisfied: lxml>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from ddgs>=9.0.0->smolagents[toolkit]) (6.0.2)
# Requirement already satisfied: httpx>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs>=9.0.0->smolagents[toolkit]) (0.28.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.31.2->smolagents[toolkit]) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.31.2->smolagents[toolkit]) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.31.2->smolagents[toolkit]) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.31.2->smolagents[toolkit]) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.31.2->smolagents[toolkit]) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.31.2->smolagents[toolkit]) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.31.2->smolagents[toolkit]) (1.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=3.1.4->smolagents[toolkit]) (3.0.3)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in /usr/local/lib/python3.12/dist-packages (from markdownify>=0.14.1->smolagents[toolkit]) (4.13.5)
# Requirement already satisfied: six<2,>=1.15 in /usr/local/lib/python3.12/dist-packages (from markdownify>=0.14.1->smolagents[toolkit]) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.3->smolagents[toolkit]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.3->smolagents[toolkit]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.3->smolagents[toolkit]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.3->smolagents[toolkit]) (2025.10.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.9.4->smolagents[toolkit]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.9.4->smolagents[toolkit]) (2.19.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4<5,>=4.9->markdownify>=0.14.1->smolagents[toolkit]) (2.8)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs>=9.0.0->smolagents[toolkit]) (4.11.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs>=9.0.0->smolagents[toolkit]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs>=9.0.0->smolagents[toolkit]) (0.16.0)
# Requirement already satisfied: brotli in /usr/local/lib/python3.12/dist-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs>=9.0.0->smolagents[toolkit]) (1.1.0)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.12/dist-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs>=9.0.0->smolagents[toolkit]) (4.3.0)
# Requirement already satisfied: socksio==1.* in /usr/local/lib/python3.12/dist-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs>=9.0.0->smolagents[toolkit]) (1.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->smolagents[toolkit]) (0.1.2)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs>=9.0.0->smolagents[toolkit]) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs>=9.0.0->smolagents[toolkit]) (4.1.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs>=9.0.0->smolagents[toolkit]) (1.3.1)
# Requirement already satisfied: smolagents[litellm] in /usr/local/lib/python3.12/dist-packages (1.22.0)
# Requirement already satisfied: huggingface-hub>=0.31.2 in /usr/local/lib/python3.12/dist-packages (from smolagents[litellm]) (0.36.0)
# Requirement already satisfied: requests>=2.32.3 in /usr/local/lib/python3.12/dist-packages (from smolagents[litellm]) (2.32.4)
# Requirement already satisfied: rich>=13.9.4 in /usr/local/lib/python3.12/dist-packages (from smolagents[litellm]) (13.9.4)
# Requirement already satisfied: jinja2>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from smolagents[litellm]) (3.1.6)
# Requirement already satisfied: pillow>=10.0.1 in /usr/local/lib/python3.12/dist-packages (from smolagents[litellm]) (11.3.0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from smolagents[litellm]) (1.2.1)
# Collecting litellm>=1.60.2 (from smolagents[litellm])
#   Downloading litellm-1.79.1-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.31.2->smolagents[litellm]) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.31.2->smolagents[litellm]) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.31.2->smolagents[litellm]) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.31.2->smolagents[litellm]) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.31.2->smolagents[litellm]) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.31.2->smolagents[litellm]) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.31.2->smolagents[litellm]) (1.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=3.1.4->smolagents[litellm]) (3.0.3)
# Requirement already satisfied: aiohttp>=3.10 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.60.2->smolagents[litellm]) (3.13.2)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from litellm>=1.60.2->smolagents[litellm]) (8.3.0)
# Collecting fastuuid>=0.13.0 (from litellm>=1.60.2->smolagents[litellm])
#   Downloading fastuuid-0.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: httpx>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.60.2->smolagents[litellm]) (0.28.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.60.2->smolagents[litellm]) (8.7.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.60.2->smolagents[litellm]) (4.25.1)
# Requirement already satisfied: openai>=1.99.5 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.60.2->smolagents[litellm]) (1.109.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.60.2->smolagents[litellm]) (2.11.10)
# Requirement already satisfied: tiktoken>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.60.2->smolagents[litellm]) (0.12.0)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.12/dist-packages (from litellm>=1.60.2->smolagents[litellm]) (0.22.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.3->smolagents[litellm]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.3->smolagents[litellm]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.3->smolagents[litellm]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.3->smolagents[litellm]) (2025.10.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.9.4->smolagents[litellm]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.9.4->smolagents[litellm]) (2.19.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.60.2->smolagents[litellm]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.60.2->smolagents[litellm]) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.60.2->smolagents[litellm]) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.60.2->smolagents[litellm]) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.60.2->smolagents[litellm]) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.60.2->smolagents[litellm]) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.60.2->smolagents[litellm]) (1.22.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.23.0->litellm>=1.60.2->smolagents[litellm]) (4.11.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.23.0->litellm>=1.60.2->smolagents[litellm]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.23.0->litellm>=1.60.2->smolagents[litellm]) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata>=6.8.0->litellm>=1.60.2->smolagents[litellm]) (3.23.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.60.2->smolagents[litellm]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.60.2->smolagents[litellm]) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.60.2->smolagents[litellm]) (0.28.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->smolagents[litellm]) (0.1.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.99.5->litellm>=1.60.2->smolagents[litellm]) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.99.5->litellm>=1.60.2->smolagents[litellm]) (0.11.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai>=1.99.5->litellm>=1.60.2->smolagents[litellm]) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.5.0->litellm>=1.60.2->smolagents[litellm]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.5.0->litellm>=1.60.2->smolagents[litellm]) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.5.0->litellm>=1.60.2->smolagents[litellm]) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken>=0.7.0->litellm>=1.60.2->smolagents[litellm]) (2024.11.6)
# Downloading litellm-1.79.1-py3-none-any.whl (10.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 66.0 MB/s eta 0:00:00
# Downloading fastuuid-0.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (278 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.1/278.1 kB 20.1 MB/s eta 0:00:00
# Installing collected packages: fastuuid, litellm
# Successfully installed fastuuid-0.14.0 litellm-1.79.1

# %% [markdown]
# # `smolagents`

# %% [markdown]
# <div class="flex justify-center">
#     <img src="https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/smolagents/license_to_call.png" style="max-width:700px"/>
# </div>

# %% [markdown]
# ## What is smolagents?

# %% [markdown]
# `smolagents` is an open-source Python library designed to make it extremely easy to build and run agents using just a few lines of code.
#
# Key features of `smolagents` include:
#
# ✨ **Simplicity**: The logic for agents fits in ~thousand lines of code. We kept abstractions to their minimal shape above raw code!
#
# 🧑‍💻 **First-class support for Code Agents**: [`CodeAgent`](https://huggingface.co/docs/smolagents/main/en/reference/agents#smolagents.CodeAgent) writes its actions in code (as opposed to "agents being used to write code") to invoke tools or perform computations, enabling natural composability (function nesting, loops, conditionals). To make it secure, we support [executing in sandboxed environment](https://huggingface.co/docs/smolagents/main/en/tutorials/secure_code_execution) via [E2B](https://e2b.dev/) or via Docker.
#
# 📡 **Common Tool-Calling Agent Support**: In addition to CodeAgents, [`ToolCallingAgent`](https://huggingface.co/docs/smolagents/main/en/reference/agents#smolagents.ToolCallingAgent) supports usual JSON/text-based tool-calling for scenarios where that paradigm is preferred.
#
# 🤗 **Hub integrations**: Seamlessly share and load agents and tools to/from the Hub as Gradio Spaces.
#
# 🌐 **Model-agnostic**: Easily integrate any large language model (LLM), whether it's hosted on the Hub via [Inference providers](https://huggingface.co/docs/inference-providers/index), accessed via APIs such as OpenAI, Anthropic, or many others via LiteLLM integration, or run locally using Transformers or Ollama. Powering an agent with your preferred LLM is straightforward and flexible.
#
# 👁️ **Modality-agnostic**: Beyond text, agents can handle vision, video, and audio inputs, broadening the range of possible applications. Check out [this tutorial](https://huggingface.co/docs/smolagents/main/en/examples/web_browser) for vision.
#
# 🛠️ **Tool-agnostic**: You can use tools from any [MCP server](https://huggingface.co/docs/smolagents/main/en/reference/tools#smolagents.ToolCollection.from_mcp), from [LangChain](https://huggingface.co/docs/smolagents/main/en/reference/tools#smolagents.Tool.from_langchain), you can even use a [Hub Space](https://huggingface.co/docs/smolagents/main/en/reference/tools#smolagents.Tool.from_space) as a tool.
#
# 💻 **CLI Tools**: Comes with command-line utilities (smolagent, webagent) for quickly running agents without writing boilerplate code.

# %% [markdown]
# ## Quickstart

# %% [markdown]
# Get started with smolagents in just a few minutes! This guide will show you how to create and run your first agent.

# %% [markdown]
# ### Installation

# %% [markdown]
# Install smolagents with pip:
#
# ```bash
# pip install 'smolagents[toolkit]'  # Includes default tools like web search
# ```

# %% [markdown]
# ### Create Your First Agent

# %% [markdown]
# Here's a minimal example to create and run an agent:

# %%
from smolagents import CodeAgent, InferenceClientModel

# Initialize a model (using Hugging Face Inference API)
model = InferenceClientModel()  # Uses a default model

# Create an agent with no tools
agent = CodeAgent(tools=[], model=model)

# Run the agent with a task
result = agent.run("Calculate the sum of numbers from 1 to 10")
print(result)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Calculate the sum of numbers from 1 to 10                                                                       │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen2.5-Coder-32B-Instruct ────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Calculate the sum of numbers from 1 to 10
#   sum_of_numbers = sum(range(1, 11))
#   final_answer(sum_of_numbers)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: 55
# [Step 1: Duration 5.68 seconds| Input tokens: 2,036 | Output tokens: 94]
# 55

# %% [markdown]
# That's it! Your agent will use Python code to solve the task and return the result.

# %% [markdown]
# ### Adding Tools

# %% [markdown]
# Let's make our agent more capable by adding some tools:

# %%
from smolagents import CodeAgent, InferenceClientModel, DuckDuckGoSearchTool

model = InferenceClientModel()
agent = CodeAgent(
    tools=[DuckDuckGoSearchTool()],
    model=model,
)

# Now the agent can search the web!
result = agent.run("What is the current weather in Paris?")
print(result)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ What is the current weather in Paris?                                                                           │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen2.5-Coder-32B-Instruct ────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   weather_info = web_search(query="current weather in Paris")
#   print(weather_info)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [Paris, Ville de Paris, France Weather Forecast |
# AccuWeather](https://www.accuweather.com/en/fr/paris/623/weather-forecast/623)
# Paris , Ville de Paris , France Weather Forecast, with current conditions, wind, air quality, and what to expect
# for the next 3 days.
#
# [10 Day Weather - Paris, France - The Weather
# Channel](https://weather.com/weather/tenday/l/1a8af5b9d8971c46dd5a52547f9221e22cd895d8d8639267a87df614d0912830)
# Be prepared with the most accurate 10-day forecast for Paris , France with highs, lows, chance of precipitation
# from The Weather Channel and Weather .com
#
# [Paris, Paris, France 14 day weather forecast -
# timeanddate.com](https://www.timeanddate.com/weather/france/paris/ext)
# Currently: 52 °F. Low clouds. ( Weather station: Villacoublay, France). See more current weather
#
# [Local Weather Daily Forecasts, Radar Maps, Hurricane Updates, and ... -
# MSN](https://www.msn.com/en-us/weather/forecast/in-Paris,Île-de-France?loc=eyJsIjoiUGFyaXMiLCJyIjoiw45sZS1kZS1GcmFu
# Y2UiLCJjIjoiRnJhbmNlIiwiaSI6IkZSIiwiZyI6ImVuLXVzIiwieCI6IjIuMzExOTIxMDYiLCJ5IjoiNDguODcyNDA2OTkifQ==)
# Get accurate hourly forecasts for today, tonight, and tomorrow, along with 10-day daily forecasts and weather radar
# with MSN Weather . Stay updated on precipitation, severe weather warnings, air ...
#
# [Weather in Paris, France - 7-Day Forecast & Live Conditions](https://weather.now/fr/paris)
# Get the latest weather forecast for Paris , France. View live conditions, a 7-day forecast, hourly updates, air
# quality index, and more.
#
# [Weather today - Paris, France](https://www.weather-atlas.com/en/france/paris)
# Paris , France - Current temperature and weather conditions. Detailed hourly weather forecast for today - including
# weather conditions, temperature, pressure, humidity, precipitation, dewpoint, wind, visibility, and UV index data.
#
# [Paris - BBC Weather](https://www.bbc.com/weather/2988507)
# 14-day weather forecast for Paris .BBC Weather in association with MeteoGroup All times are Central European
# Standard Time (Europe/ Paris , GMT+1) unless otherwise stated.
#
# [Weather Paris - meteoblue](https://www.meteoblue.com/en/weather/week/paris_france_2988507)
# Today's and tonight's professional weather forecast for Paris . Precipitation radar, HD satellite images, and
# current weather warnings, hourly temperature, chance of rain, and sunshine hours.
#
# [METEO Paris (75000) - Météo-France](https://previ.meteofrance.com/previsions-meteo-france/paris/75000)
# METEO FRANCE - Retrouvez les prévisions METEO PARIS de Météo-France pour aujourd'hui, demain et jusqu'à 15 jours,
# ainsi que les prévisions météos locales par heure et les prévisions de pluie.
#
# [Paris (France) weather - Met Office](https://weather.metoffice.gov.uk/forecast/u09tvnxyj)
# Paris 7 day weather forecast including weather warnings, temperature, rain, wind, visibility, humidity and UV
#
# Out: None
# [Step 1: Duration 4.64 seconds| Input tokens: 2,083 | Output tokens: 52]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   weather_info_timeanddate = web_search(query="https://www.timeanddate.com/weather/france/paris/ext")
#   print(weather_info_timeanddate)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [Paris, Paris, France 14 day weather forecast -
# timeanddate.com](https://www.timeanddate.com/weather/france/paris/ext)
# 2 Week Extended Forecast in Paris, Paris, France ... Hour-by-hour weather for Paris next 7 days
#
# [14-Day Weather Paris - Extended Forecast 14-Day in Paris
# (Île-de-France)](https://world-weather.info/forecast/france/paris/14days/)
# Detailed Weather Forecast ⚡ in Paris for 14 days - 🌡️ air temperature, RealFeel, wind, precipitation, atmospheric
# pressure in Paris, Île-de-France for 2 weeks - World-Weather.info
#
# [Paris, France 16 day weather forecast | The Weather
# Outlook](https://www.theweatheroutlook.com/forecast/48d85-02d35/paris--paris--france)
# Get the detailed weather forecast for Paris, Paris, France. Access daily, 10 day and 16 day views, maps, meteograms
# and timelines for accurate predicitions.
#
# [15-day weather forecast for Paris - Top weather site for
# l'île-de-France](https://www.meteo-paris.com/en/ile-de-france/forecasts)
# Discover the 15-day weather forecast for Paris and its surroundings on Weather Paris. Plan your activities up to 15
# days ahead with our reliable weather forecasts: temperatures, precipitation, wind...
#
# [10 Day Weather - Paris, France - The Weather
# Channel](https://weather.com/weather/tenday/l/1a8af5b9d8971c46dd5a52547f9221e22cd895d8d8639267a87df614d0912830)
# Be prepared with the most accurate 10-day forecast for Paris, France with highs, lows, chance of precipitation from
# The Weather Channel and Weather.com
#
# [14-day weather forecast for France](https://weatherandclimate.co.uk/france/weather-forecast/)
# The weather for the next 14 days in France. Find out about the temperature, precipitation, and wind for the next
# two weeks.
#
# [Weather for Paris, Paris, France - timeanddate.com](https://www.timeanddate.com/weather/france/paris)
# Current weather in Paris and forecast for today, tomorrow, and next 14 days
#
# [15 day weather forecast for Paris - Extended
# Forecast](https://www.extendedforecast.net/forecasts/15-day/france/paris/)
# 15 day extended weather forecast for Paris: Temperature, rain, warnings and maps.
#
# [Paris, IDF, FR 14 Days Weather - The Weather
# Network](https://www.theweathernetwork.com/en/city/fr/ile-de-france/paris/14-days)
# Paris, IDF, FR temperature trend for the next 14 Days. Find daytime highs and nighttime lows from
# TheWeatherNetwork.com.
#
# [10-Day Weather Forecast for Paris - Detailed Weather for 10
# days](https://world-weather.info/forecast/france/paris/10days/)
# World France Île-de-France Weather in Paris 10-Day Weather for Paris Extended weather forecast for Paris
# (Île-de-France) for the next 10 days. Information about air temperature, wind, pressure, humidity, sunrise, and
# sunset.
#
# Out: None
# [Step 2: Duration 6.11 seconds| Input tokens: 5,122 | Output tokens: 150]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   weather_info_timeanddate = web_search(query="https://www.timeanddate.com/weather/france/paris/ext")
#   current_weather = re.search(r'Currently: (\d+ °F\.\s[A-Za-z]+\.)', weather_info_timeanddate).group(0)
#   final_answer(current_weather)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Code execution failed at line 'current_weather = re.search(r'Currently: (\d+ °F\.\s[A-Za-z\]+\.)',
# weather_info_timeanddate).group(0)' due to: InterpreterError: The variable `re` is not defined.
# [Step 3: Duration 9.01 seconds| Input tokens: 9,082 | Output tokens: 294]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 4 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import re
#   weather_info_timeanddate = web_search(query="https://www.timeanddate.com/weather/france/paris/ext")
#   current_weather = re.search(r'Currently: (\d+ °F\. [A-Za-z]+)', weather_info_timeanddate).group(0)
#   final_answer(current_weather)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Code execution failed at line 'current_weather = re.search(r'Currently: (\d+ °F\. [A-Za-z\]+)',
# weather_info_timeanddate).group(0)' due to: InterpreterError: Object None has no attribute group
# [Step 4: Duration 7.19 seconds| Input tokens: 13,389 | Output tokens: 406]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 5 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import re
#   weather_info_timeanddate = web_search(query="https://www.timeanddate.com/weather/france/paris/ext")
#   current_weather_match = re.search(r'Currently:\s+(\d+)\s+°F\s+\(([^)]+)\)', weather_info_timeanddate)
#   if current_weather_match:
#       current_temperature = current_weather_match.group(1)
#       current_condition = current_weather_match.group(2)
#       current_weather = f"{current_temperature} °F, {current_condition}"
#       print(current_weather)
#   else:
#       print("No weather information found.")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# No weather information found.
#
# Out: None
# [Step 5: Duration 13.44 seconds| Input tokens: 18,008 | Output tokens: 611]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 6 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import re
#   weather_info_timeanddate = web_search(query="https://www.timeanddate.com/weather/france/paris/ext")
#   current_weather_match = re.search(r'Currently:\s*(\d+)\s*°F\s*([A-Za-z\s]+)', weather_info_timeanddate)
#   if current_weather_match:
#       current_temperature = current_weather_match.group(1)
#       current_condition = current_weather_match.group(2).strip()
#       current_weather = f"{current_temperature} °F, {current_condition}"
#       print(current_weather)
#   else:
#       print("No weather information found.")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# No weather information found.
#
# Out: None
# [Step 6: Duration 10.00 seconds| Input tokens: 23,028 | Output tokens: 801]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 7 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import re
#   weather_info_timeanddate = web_search(query="https://www.timeanddate.com/weather/france/paris/ext")
#   currently_line_match = re.search(r'Currently:\s*[\d\s°CF\.]+\s*([A-Za-z\s]+)', weather_info_timeanddate)
#
#   if currently_line_match:
#       current_weather = currently_line_match.group(0).split(':')[1].strip()
#       print(current_weather)
#   else:
#       print("No weather information found.")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# 50 °F . Clear
#
# Out: 50 °F . Clear
# [Step 7: Duration 10.07 seconds| Input tokens: 28,437 | Output tokens: 976]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 8 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import re
#   weather_info_timeanddate = web_search(query="https://www.timeanddate.com/weather/france/paris/ext")
#   currently_line_match = re.search(r'Currently:\s*[\d\s°CF\.]+\s*([A-Za-z\s]+)', weather_info_timeanddate)
#
#   if currently_line_match:
#       current_weather = currently_line_match.group(1).strip()
#       print(current_weather)
#   else:
#       print("No weather information found.")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Drizzle
#
# Out: Drizzle
# [Step 8: Duration 8.63 seconds| Input tokens: 34,206 | Output tokens: 1,127]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 9 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_answer("Drizzle")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: Drizzle
# [Step 9: Duration 4.69 seconds| Input tokens: 40,296 | Output tokens: 1,174]
# Drizzle

# %% [markdown]
# ### Using Different Models

# %% [markdown]
# You can use various models with your agent:

# %%
# Using a specific model from Hugging Face
model = InferenceClientModel(model_id="meta-llama/Llama-2-70b-chat-hf")

# Using OpenAI/Anthropic (requires 'smolagents[litellm]')
from smolagents import LiteLLMModel
model = LiteLLMModel(model_id="gpt-4")

# Using local models (requires 'smolagents[transformers]')
from smolagents import TransformersModel
model = TransformersModel(model_id="meta-llama/Llama-2-7b-chat-hf")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     401     try:
# --> 402         response.raise_for_status()
#     403     except HTTPError as e:
#
# /usr/local/lib/python3.12/dist-packages/requests/models.py in raise_for_status(self)
#    1025         if http_error_msg:
# -> 1026             raise HTTPError(http_error_msg, response=self)
#    1027
#
# HTTPError: 403 Client Error: Forbidden for url: https://huggingface.co/meta-llama/Llama-2-7b-chat-hf/resolve/main/config.json
#
# The above exception was the direct cause of the following exception:
#
# GatedRepoError                            Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/transformers/utils/hub.py in cached_files(path_or_repo_id, filenames, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     478             # This is slightly better for only 1 file
# --> 479             hf_hub_download(
#     480                 path_or_repo_id,
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     113
# --> 114         return fn(*args, **kwargs)
#     115
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#    1006     else:
# -> 1007         return _hf_hub_download_to_cache_dir(
#    1008             # Destination
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#    1113         # Otherwise, raise appropriate error
# -> 1114         _raise_on_head_call_error(head_call_error, force_download, local_files_only)
#    1115
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py in _raise_on_head_call_error(head_call_error, force_download, local_files_only)
#    1654         # Unauthorized => likely a token issue => let's raise the actual error
# -> 1655         raise head_call_error
#    1656     else:
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py in _get_metadata_or_catch_error(repo_id, filename, repo_type, revision, endpoint, proxies, etag_timeout, headers, token, local_files_only, relative_filename, storage_folder)
#    1542             try:
# -> 1543                 metadata = get_hf_file_metadata(
#    1544                     url=url, proxies=proxies, timeout=etag_timeout, headers=headers, token=token, endpoint=endpoint
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     113
# --> 114         return fn(*args, **kwargs)
#     115
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py in get_hf_file_metadata(url, token, proxies, timeout, library_name, library_version, user_agent, headers, endpoint)
#    1459     # Retrieve metadata
# -> 1460     r = _request_wrapper(
#    1461         method="HEAD",
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py in _request_wrapper(method, url, follow_relative_redirects, **params)
#     282     if follow_relative_redirects:
# --> 283         response = _request_wrapper(
#     284             method=method,
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py in _request_wrapper(method, url, follow_relative_redirects, **params)
#     306     response = http_backoff(method=method, url=url, **params)
# --> 307     hf_raise_for_status(response)
#     308     return response
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     418             )
# --> 419             raise _format(GatedRepoError, message, response) from e
#     420
#
# GatedRepoError: 403 Client Error. (Request ID: Root=1-690f57a4-7a93397243e4014560ff4d5a;e6aba4b0-73c9-45ed-ab77-66c9bcee8936)
#
# Cannot access gated repo for url https://huggingface.co/meta-llama/Llama-2-7b-chat-hf/resolve/main/config.json.
# Access to model meta-llama/Llama-2-7b-chat-hf is restricted and you are not in the authorized list. Visit https://huggingface.co/meta-llama/Llama-2-7b-chat-hf to ask for access.
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/smolagents/models.py in __init__(self, model_id, device_map, torch_dtype, trust_remote_code, model_kwargs, max_new_tokens, max_tokens, **kwargs)
#     867         try:
# --> 868             self.model = AutoModelForImageTextToText.from_pretrained(
#     869                 model_id,
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     548
# --> 549             config, kwargs = AutoConfig.from_pretrained(
#     550                 pretrained_model_name_or_path,
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/auto/configuration_auto.py in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1331
# -> 1332         config_dict, unused_kwargs = PretrainedConfig.get_config_dict(pretrained_model_name_or_path, **kwargs)
#    1333         has_remote_code = "auto_map" in config_dict and "AutoConfig" in config_dict["auto_map"]
#
# /usr/local/lib/python3.12/dist-packages/transformers/configuration_utils.py in get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     661         # Get config dict associated with the base config file
# --> 662         config_dict, kwargs = cls._get_config_dict(pretrained_model_name_or_path, **kwargs)
#     663         if config_dict is None:
#
# /usr/local/lib/python3.12/dist-packages/transformers/configuration_utils.py in _get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     720                 # Load from local folder or from cache or download from model Hub and cache
# --> 721                 resolved_config_file = cached_file(
#     722                     pretrained_model_name_or_path,
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/hub.py in cached_file(path_or_repo_id, filename, **kwargs)
#     321     """
# --> 322     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     323     file = file[0] if file is not None else file
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/hub.py in cached_files(path_or_repo_id, filenames, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     542                 return None
# --> 543             raise OSError(
#     544                 "You are trying to access a gated repo.\nMake sure to have access to it at "
#
# OSError: You are trying to access a gated repo.
# Make sure to have access to it at https://huggingface.co/meta-llama/Llama-2-7b-chat-hf.
# 403 Client Error. (Request ID: Root=1-690f57a4-7a93397243e4014560ff4d5a;e6aba4b0-73c9-45ed-ab77-66c9bcee8936)
#
# Cannot access gated repo for url https://huggingface.co/meta-llama/Llama-2-7b-chat-hf/resolve/main/config.json.
# Access to model meta-llama/Llama-2-7b-chat-hf is restricted and you are not in the authorized list. Visit https://huggingface.co/meta-llama/Llama-2-7b-chat-hf to ask for access.
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3150682549.py in <cell line: 0>()
#       8 # Using local models (requires 'smolagents[transformers]')
#       9 from smolagents import TransformersModel
# ---> 10 model = TransformersModel(model_id="meta-llama/Llama-2-7b-chat-hf")
#
# /usr/local/lib/python3.12/dist-packages/smolagents/models.py in __init__(self, model_id, device_map, torch_dtype, trust_remote_code, model_kwargs, max_new_tokens, max_tokens, **kwargs)
#     891                 raise e
#     892         except Exception as e:
# --> 893             raise ValueError(f"Failed to load tokenizer and model for {model_id=}: {e}") from e
#     894         super().__init__(
#     895             flatten_messages_as_text=not self._is_vlm, model_id=model_id, max_new_tokens=max_new_tokens, **kwargs
#
# ValueError: Failed to load tokenizer and model for model_id='meta-llama/Llama-2-7b-chat-hf': You are trying to access a gated repo.
# Make sure to have access to it at https://huggingface.co/meta-llama/Llama-2-7b-chat-hf.
# 403 Client Error. (Request ID: Root=1-690f57a4-7a93397243e4014560ff4d5a;e6aba4b0-73c9-45ed-ab77-66c9bcee8936)
#
# Cannot access gated repo for url https://huggingface.co/meta-llama/Llama-2-7b-chat-hf/resolve/main/config.json.
# Access to model meta-llama/Llama-2-7b-chat-hf is restricted and you are not in the authorized list. Visit https://huggingface.co/meta-llama/Llama-2-7b-chat-hf to ask for access.

# %% [markdown]
# ## Next Steps

# %% [markdown]
# - Learn how to set up smolagents with various models and tools in the [Installation Guide](https://huggingface.co/docs/smolagents/main/en/installation)
# - Check out the [Guided Tour](https://huggingface.co/docs/smolagents/main/en/guided_tour) for more advanced features
# - Learn about [building custom tools](https://huggingface.co/docs/smolagents/main/en/tutorials/tools)
# - Explore [secure code execution](https://huggingface.co/docs/smolagents/main/en/tutorials/secure_code_execution)
# - See how to create [multi-agent systems](https://huggingface.co/docs/smolagents/main/en/tutorials/building_good_agents)
#
# <div class="mt-10">
#   <div class="w-full flex flex-col space-y-4 md:space-y-0 md:grid md:grid-cols-2 md:gap-y-4 md:gap-x-5">
#     <a class="!no-underline border dark:border-gray-700 p-5 rounded-lg shadow hover:shadow-lg" href="./guided_tour"
#       ><div class="w-full text-center bg-gradient-to-br from-blue-400 to-blue-500 rounded-lg py-1.5 font-semibold mb-5 text-white text-lg leading-relaxed">Guided tour</div>
#       <p class="text-gray-700">Learn the basics and become familiar with using Agents. Start here if you are using Agents for the first time!</p>
#     </a>
#     <a class="!no-underline border dark:border-gray-700 p-5 rounded-lg shadow hover:shadow-lg" href="./examples/text_to_sql"
#       ><div class="w-full text-center bg-gradient-to-br from-indigo-400 to-indigo-500 rounded-lg py-1.5 font-semibold mb-5 text-white text-lg leading-relaxed">How-to guides</div>
#       <p class="text-gray-700">Practical guides to help you achieve a specific goal: create an agent to generate and test SQL queries!</p>
#     </a>
#     <a class="!no-underline border dark:border-gray-700 p-5 rounded-lg shadow hover:shadow-lg" href="./conceptual_guides/intro_agents"
#       ><div class="w-full text-center bg-gradient-to-br from-pink-400 to-pink-500 rounded-lg py-1.5 font-semibold mb-5 text-white text-lg leading-relaxed">Conceptual guides</div>
#       <p class="text-gray-700">High-level explanations for building a better understanding of important topics.</p>
#    </a>
#     <a class="!no-underline border dark:border-gray-700 p-5 rounded-lg shadow hover:shadow-lg" href="./tutorials/building_good_agents"
#       ><div class="w-full text-center bg-gradient-to-br from-purple-400 to-purple-500 rounded-lg py-1.5 font-semibold mb-5 text-white text-lg leading-relaxed">Tutorials</div>
#       <p class="text-gray-700">Horizontal tutorials that cover important aspects of building agents.</p>
#     </a>
#   </div>
# </div>
